# %%
import xpress as xp
import numpy as np
import pandas as pd
import time

# %%
print("="*70)
print("Loading Data")
print("="*70)
# Out:
# ======================================================================
# Loading Data
# ======================================================================

# %%
# Load distance matrix
distance_matrix = np.loadtxt('distance_matrix.csv', delimiter=',')
stations = pd.read_csv('station_data.csv')
pois = pd.read_csv('edinburgh_pois.csv')

# %%
I = distance_matrix.shape[0]  # Number of POIs (demand points)
J = distance_matrix.shape[1] # Number of candidate stations

# %%
print("="*70)
print("DEFINE MODEL PARAMETERS")
print("="*70)
# Out:
# ======================================================================
# DEFINE MODEL PARAMETERS
# ======================================================================

# %%
# IMPORTANT: Set the number of facilities to locate
p = 15  # Change this to test different scenarios

print(f"\n{'='*70}")
print(f"MODEL PARAMETERS")
print(f"{'='*70}")
print(f"Number of POIs (I):                {I}")
print(f"Number of candidate stations (J):  {J}")
print(f"Number of stations to locate (p):  {p}")
# Out:
# ======================================================================
# MODEL PARAMETERS
# ======================================================================
# Number of POIs (I):                33669
# Number of candidate stations (J):  85
# Number of stations to locate (p):  15

# %%
print("="*70)
print("CREATE XPRESS PROBLEM")
print("="*70)
# Out:
# ======================================================================
# CREATE XPRESS PROBLEM
# ======================================================================

# %%
prob = xp.problem(name='p_centre_bike_stations')

# %%
print("="*70)
print("DEFINE DECISION VARIABLES")
print("="*70)
# Out:
# ======================================================================
# DEFINE DECISION VARIABLES
# ======================================================================

# %%
# Y[j] = 1 if facility j is opened, 0 otherwise
Y = {j: prob.addVariable(vartype=xp.binary, name=f'Y_{j}') for j in range(J)}

# X[i,j] = 1 if demand point i is assigned to station j, 0 otherwise
X = {(i, j): prob.addVariable(vartype=xp.binary, name=f'X_{i}_{j}') 
     for i in range(I) for j in range(J)}

# Q = maximum service distance (minimax objective)
Q = prob.addVariable(name='Q', lb=0)

print(f"Created {J} Y variables (station selection)")
print(f" Created {I*J:,} X variables (POI-station assignments)")
print(f" Created 1 W variable (minimax distance)")
print(f"  Total variables: {J + I*J + 1:,}")
# Out:
# Created 85 Y variables (station selection)
#  Created 2,861,865 X variables (POI-station assignments)
#  Created 1 W variable (minimax distance)
#   Total variables: 2,861,951

# %%
print("="*70)
print("ADD CONSTRAINTS")
print("="*70)
# Out:
# ======================================================================
# ADD CONSTRAINTS
# ======================================================================

# %%
# CONSTRAINT 1: Each POI must be assigned to exactly one station
print("  Adding constraint 1: POI assignment (each POI assigned to exactly one station)...")
for i in range(I):
    prob.addConstraint(xp.Sum(X[i, j] for j in range(J)) == 1)

# CONSTRAINT 2: Exactly p stations must be opened
print(f"  Adding constraint 2: Facility count (open exactly {p} stations)...")
prob.addConstraint(xp.Sum(Y[j] for j in range(J)) == p)

# CONSTRAINT 3: Assignment only to open stations (linking constraints)
print("  Adding constraint 3: Linking constraints (assign only to open stations)...")
for i in range(I):
    for j in range(J):
        prob.addConstraint(X[i, j] <= Y[j])

# CONSTRAINT 4: Minimax distance constraint
print("  Adding constraint 4: Minimax distance (Q >= distance to assigned station)...")
for i in range(I):
    prob.addConstraint(
        xp.Sum(distance_matrix[i, j] * X[i, j] for j in range(J)) <= Q)
# Out:
#   Adding constraint 1: POI assignment (each POI assigned to exactly one station)...
#   Adding constraint 2: Facility count (open exactly 15 stations)...
#   Adding constraint 3: Linking constraints (assign only to open stations)...
#   Adding constraint 4: Minimax distance (Q >= distance to assigned station)...

# %%
print("="*70)
print("SET OBJECTIVE FUNCTION")
print("="*70)
# Out:
# ======================================================================
# SET OBJECTIVE FUNCTION
# ======================================================================

# %%
# Minimize W (the maximum service distance)
prob.setObjective(Q, sense=xp.minimize)

# %%
prob.write("problem","lp")

# %%
print("\n" + "="*70)
print("SOLVING MODEL...")
print("="*70 + "\n")

start_solve = time.time()

# Solve the problem
xp.setOutputEnabled(True)
prob.solve()

solve_time = time.time() - start_solve
# Out:
# ======================================================================
# SOLVING MODEL...
# ======================================================================
#
# FICO Xpress v9.7.0, Hyper, solve started 13:20:11, Nov 6, 2025
# Heap usage: 1762MB (peak 1762MB, 573MB system)
# Minimizing MILP p_centre_bike_stations using up to 8 threads and up to 8192MB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = 1
# Original problem has:
#    2929204 rows      2861951 cols     11481214 elements   2861950 entities
# Presolved problem has:
#    2929204 rows      2861951 cols      9089667 elements   2861950 entities
# Presolve finished in 858 seconds
# Heap usage: 3361MB (peak 4508MB, 573MB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.82e-02,  1.99e+01] / [ 2.50e-07,  2.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.50e+01] / [ 9.45e-01,  4.67e+02]
#   Objective      [min,max] : [ 1.00e+00,  1.00e+00] / [ 1.00e+00,  1.00e+00]
# Autoscaling applied standard scaling
#
# Will try to keep branch and bound tree memory usage below 5.9GB
#  *** Solution found:    12.955800   Time: 864.31    Heuristic: e ***
# Starting concurrent solve with dual (1 thread) and barrier (7 threads)
#
#               Concurrent-Solve, 872s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#           dual crash     |           factorize
#  D  7.5992441   .0000000 |           factorize
#  D  7.5995411   .0000000 |  B  23.556298 -3816538.8
#  D  7.6002827   .0000000 |  B  23.556298 -3816538.8
#  D  7.6007814   .0000000 |  B  28.915703 -5325858.7
#  D  7.6020274   .0000000 |  B  28.915703 -5325858.7
#  D  7.6021093   .0000000 |  B  28.915703 -5325858.7
#  D  7.6022858   .0000000 |  B  55.015110 -5005982.5
#  D  7.6025060   .0000000 |  B  55.015110 -5005982.5
#  D  7.6033069   .0000000 |  B  55.808294 -398811.89
#  D  7.6039632   .0000000 |  B  55.808294 -398811.89
#  D  7.6047425   .0000000 |  B  55.808294 -398811.89
#  D  7.6050872   .0000000 |  B  32.711831 -421.39471
#  D  7.6054388   .0000000 |  B  32.711831 -421.39471
#  D  7.6057932   .0000000 |  B  12.671250 -65.801462
#  D  7.6061442   .0000000 |  B  12.671250 -65.801462
#  D  7.6063318   .0000000 |  B  12.671250 -65.801462
#  D  7.6065749   .0000000 |  B  12.239263 -53.492071
#  D  7.6067705   .0000000 |  B  12.239263 -53.492071
#  D  7.6069381   .0000000 |  B  11.433164 -46.849048
#
#               Concurrent-Solve, 921s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  7.6071118   .0000000 |  B  11.433164 -46.849048
#  D  7.6072720   .0000000 |  B  11.433164 -46.849048
#  D  7.6074708   .0000000 |  B  9.6878178 -24.100713
#  D  7.6075436   .0000000 |  B  9.6878178 -24.100713
#  D  7.6076822   .0000000 |  B  8.8946362 -6.0692013
#  D  7.6078285   .0000000 |  B  8.8946362 -6.0692013
#  D  7.6079502   .0000000 |  B  8.8946362 -6.0692013
#  D  7.6080596   .0000000 |  B  8.6258892 -1.7496596
#  D  7.6081555   .0000000 |  B  8.6258892 -1.7496596
#  D  7.6082600   .0000000 |  B  8.5378194  -.6536978
#  D  7.6083662   .0000000 |  B  8.5378194  -.6536978
#  D  7.6084584   .0000000 |  B  8.5378194  -.6536978
#  D  7.6085633   .0000000 |  B  8.3914034   .1230429
#  D  7.6086490   .0000000 |  B  8.3914034   .1230429
#  D  7.6087467   .0000000 |  B  8.3192975   .9917522
#  D  7.6088383   .0000000 |  B  8.3192975   .9917522
#  D  7.6089423   .0000000 |  B  8.3192975   .9917522
#  D  7.6090636   .0000000 |  B  8.2600568  1.5588591
#  D  7.6091723   .0000000 |  B  8.2600568  1.5588591
#  D  7.6093244   .0000000 |  B  8.2538854  1.5968444
#
#               Concurrent-Solve, 956s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  7.6094426   .0000000 |  B  8.2538854  1.5968444
#  D  7.6096058   .0000000 |  B  8.2538854  1.5968444
#  D  7.6097552   .0000000 |  B  8.1541905  2.8653172
#  D  7.6099000   .0000000 |  B  8.1541905  2.8653172
#  D  7.6100508   .0000000 |  B  8.1541905  2.8653172
#  D  7.6101955   .0000000 |  B  8.1039100  3.2259086
#  D  7.6103326   .0000000 |  B  8.1039100  3.2259086
#  D  7.6104223   .0000000 |  B  8.0322932  3.6688862
#  D  7.6105323   .0000000 |  B  8.0322932  3.6688862
#  D  7.6106262   .0000000 |  B  8.0322932  3.6688862
#  D  7.6107042   .0000000 |  B  7.9983393  4.6468231
#  D  7.6107954   .0000000 |  B  7.9983393  4.6468231
#  D  7.6108988   .0000000 |  B  7.9226248  5.1570601
#  D  7.6110067   .0000000 |  B  7.9226248  5.1570601
#  D  7.6110965   .0000000 |  B  7.9226248  5.1570601
#  D  7.6112004   .0000000 |  B  7.9012217  5.2114601
#  D  7.6113190   .0000000 |  B  7.9012217  5.2114601
#  D  7.6114372   .0000000 |  B  7.8457022  5.5148832
#  D  7.6115512   .0000000 |  B  7.8457022  5.5148832
#  D  7.6116591   .0000000 |  B  7.8457022  5.5148832
#
#               Concurrent-Solve, 987s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  7.6117991   .0000000 |  B  7.8154799  5.9295356
#  D  7.6119119   .0000000 |  B  7.8154799  5.9295356
#  D  7.6120664   .0000000 |  B  7.7486216  6.1475210
#  D  7.6121965   .0000000 |  B  7.7486216  6.1475210
#  D  7.6123328   .0000000 |  B  7.7486216  6.1475210
#  D  7.6124661   .0000000 |  B  7.7028181  6.5971565
#  D  7.6126101   .0000000 |  B  7.7028181  6.5971565
#  D  7.6127294   .0000000 |  B  7.6965799  6.6984962
#  D  7.6128593   .0000000 |  B  7.6965799  6.6984962
#  D  7.6129870   .0000000 |  B  7.6965799  6.6984962
#  D  7.6130629   .0000000 |  B  7.6851807  6.9290599
#  D  7.6131696   .0000000 |  B  7.6851807  6.9290599
#  D  7.6132592   .0000000 |  B  7.6337068  7.2024589
#  D  7.6133493   .0000000 |  B  7.6337068  7.2024589
#  D  7.6134554   .0000000 |  B  7.6337068  7.2024589
#  D  7.6135484   .0000000 |  B  7.6287874  7.2212104
#  D  7.6136556   .0000000 |  B  7.6287874  7.2212104
#  D  7.6138017   .0000000 |  B  7.6122072  7.3998381
#  D  7.6139126   .0000000 |  B  7.6122072  7.3998381
#  D  7.6140312   .0000000 |  B  7.6122072  7.3998381
#
#               Concurrent-Solve, 1010s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  7.6141753   .0000000 |  B  7.5900284  7.4587952
#  D  7.6143395   .0000000 |  B  7.5900284  7.4587952
#  D  7.6144650   .0000000 |  B  7.5744222  7.4935412
#  D  7.6145917   .0000000 |  B  7.5744222  7.4935412
#  D  7.6146940   .0000000 |  B  7.5744222  7.4935412
#  D  7.6147956   .0000000 |  B  7.5668938  7.4984345
#  D  7.6149237   .0000000 |  B  7.5668938  7.4984345
#  D  7.6150314   .0000000 |  B  7.5660800  7.5221605
#  D  7.6151446   .0000000 |  B  7.5660800  7.5221605
#  D  7.6152481   .0000000 |  B  7.5660800  7.5221605
#  D  7.6153462   .0000000 |  B  7.5574499  7.5309960
#  D  7.6154568   .0000000 |  B  7.5574499  7.5309960
#  D  7.6155960   .0000000 |  B  7.5565796  7.5432830
#  D  7.6157538   .0000000 |  B  7.5565796  7.5432830
#  D  7.6158910   .0000000 |  B  7.5565796  7.5432830
#  D  7.6160111   .0000000 |  B  7.5565512  7.5465534
#  D  7.6160927   .0000000 |  B  7.5565512  7.5465534
#  D  7.6162057   .0000000 |  B  7.5564143  7.5543623
#  D  7.6163359   .0000000 |  B  7.5564143  7.5543623
#  D  7.6164502   .0000000 |  B  7.5564143  7.5543623
#
#               Concurrent-Solve, 1034s
#             Dual                      Barrier
#     objective   dual inf        p.obj.     d.obj.
#  D  7.6165540   .0000000 |  B  7.5563010  7.5562912
#  D  7.6166665   .0000000 |  B  7.5563010  7.5562912
#  D  7.6167833   .0000000 |  B  7.5562980  7.5562979
#  D  7.6169048   .0000000 |  B  7.5562980  7.5562979
#  D  7.6170141   .0000000 |  B  7.5562980  7.5562979
#  D  7.6171216   .0000000 |  B  7.5562980  7.5562980
#  D  7.6172115   .0000000 |  B  7.5562980  7.5562980
#  D  7.6173188   .0000000 |           crossover
#  D  7.6174135   .0000000 |           crossover
#  D  7.6175288   .0000000 |           crossover
#  D  7.6176473   .0000000 |           crossover
#  D  7.6177701   .0000000 |           crossover
#  D  7.6178982   .0000000 |           crossover
#  D  7.6180086   .0000000 |           crossover
#  D  7.6181191   .0000000 |           crossover
#  D  7.6182515   .0000000 |           crossover
#  D  7.6184034   .0000000 |           crossover
#  D  7.6185159   .0000000 |           crossover
#  D  7.6186202   .0000000 |           crossover
#  D  7.6187204   .0000000 |           crossover
#
#               Concurrent-Solve, 1055s
#             Dual                      Barrier
#     objective   dual inf       objective   sum inf
#  D  7.6188096   .0000000 |           crossover
#  D  7.6189356   .0000000 |           crossover
#  D  7.6190567   .0000000 |           crossover
#  D  7.6191093   .0000000 |           crossover
#  D  7.6192331   .0000000 |           crossover
#  D  7.6193233   .0000000 |           crossover
#  D  7.6194108   .0000000 |           crossover
#  D  7.6194965   .0000000 |           crossover
#  D  7.6195931   .0000000 |           crossover
#  D  7.6196832   .0000000 |           crossover
#  D  7.6197701   .0000000 |           crossover
#  D  7.6199041   .0000000 |           crossover
#  D  7.6200214   .0000000 |           crossover
# ----- interrupted ------ | ------- optimal --------
# Concurrent statistics:
#            Dual: 71867 simplex iterations, 200.05s
#         Barrier: 41 barrier and 239609 simplex iterations, 115.15s
#             Barrier used 7 threads 7 cores
# , crossover used 7 threads
# Optimal solution found
#
#    Its         Obj Value      S   Ninf  Nneg        Sum Inf  Time
#      0          7.556298      P      0     0        .000000  1070
# Barrier solved problem
#   41 barrier and 239609 simplex iterations in 200.98 seconds at time 1070
#
# Final objective                       : 7.556297999999970e+00
#   Max primal violation      (abs/rel) : 8.188e-16 / 8.188e-16
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) :       0.0 /       0.0
#
# Starting root cutting & heuristics
# Deterministic mode with up to 1 additional thread
#
#  Its Type    BestSoln    BestBound   Sols    Add    Del     Gap     GInf   Time

# %%
    print("\n" + "="*70)
    print("SOLUTION SUMMARY")
    print("="*70)
    

    # Extract optimal minimax distance
    Q_optimal = prob.getSolution(Q)
    
    # Extract which stations to open
    stations_open = []
    for j in range(J):
        if prob.getSolution(Y[j]) > 0.5:  # Binary variable, so > 0.5 means 1
            stations_open.append(j)

# %%
    print(f"\n{'='*70}")
    print(f"OPTIMAL P-CENTRE RESULTS")
    print(f"{'='*70}")
    
    print(f"\n1. STATIONS TO OPEN ({len(stations_open)} out of {J}):")
    print(f"   Station indices: {stations_open}")
    
    print(f"\n   Station details:")
    optimal_stations_list = []
    for idx, j in enumerate(stations_open, 1):
        station_id = stations.iloc[j]['station_id']
        station_name = stations.iloc[j]['name']
        capacity = stations.iloc[j]['capacity']
        lat = stations.iloc[j]['lat']
        lon = stations.iloc[j]['lon']
        
        optimal_stations_list.append({
            'index': j,
            'rank': idx,
            'station_id': station_id,
            'station_name': station_name,
            'capacity': capacity,
            'latitude': lat,
            'longitude': lon
        })
        
        print(f"   {idx:2d}. [{j:2d}] {station_name:30s} (ID: {station_id}, Capacity: {capacity:2d} docks)")
    
    print(f"\n2. OPTIMAL MINIMAX DISTANCE:")
    print(f"   Maximum service distance (W*) = {Q_optimal:.4f} km")
    print(f"   ✓ All {I:,} POIs served within {Q_optimal:.4f} km of nearest station")

# %%
start_solve2 = time.time()
sol = {(i, j): prob.getSolution(X[i, j]) for i in range(I) for j in range(J)}

solution_matrix = np.zeros((I, J))
for (i, j), val in sol.items():
    solution_matrix[i, j] = val

assignments = np.argmax(solution_matrix, axis=1)
solve_time2 = time.time() - start_solve
print(solve_time2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 start_solve2 = time.time()
# ----> 2 sol = {(i, j): prob.getSolution(X[i, j]) for i in range(I) for j in range(J)}
#       4 solution_matrix = np.zeros((I, J))
#       5 for (i, j), val in sol.items():
#
# KeyboardInterrupt:

# %%
    print(f"   All {I:,} POIs assigned: {len(assignments) == I}")
    
    # Count POIs per station
    pois_per_station = {}
    distances_per_station = {}
    
    for i, j in assignments.items():
        if j not in pois_per_station:
            pois_per_station[j] = 0
            distances_per_station[j] = []
        pois_per_station[j] += 1
        distances_per_station[j].append(distance_matrix[i, j])
    
    print(f"\n   POIs assigned per station:")
    for rank, j in enumerate(stations_open, 1):
        count = pois_per_station.get(j, 0)
        avg_dist = np.mean(distances_per_station.get(j, ))
        max_dist = np.max(distances_per_station.get(j, ))
        
        print(f"   {rank:2d}. {stations.iloc[j]['name']:30s}: {count:5,} POIs (avg: {avg_dist:.3f} km, max: {max_dist:.3f} km)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(f"   All {I:,} POIs assigned: {len(assignments) == I}")
#       3 # Count POIs per station
#       4 pois_per_station = {}
#
# NameError: name 'assignments' is not defined

# %%
    all_assigned_distances = [distance_matrix[i, assignments[i]] for i in range(I)]
    
    print(f"\n4. DISTANCE STATISTICS:")
    print(f"   Mean distance: {np.mean(all_assigned_distances):.4f} km")
    print(f"   Median distance: {np.median(all_assigned_distances):.4f} km")
    print(f"   Std Dev: {np.std(all_assigned_distances):.4f} km")
    print(f"   Min distance: {np.min(all_assigned_distances):.4f} km")
    print(f"   Max distance (W*): {np.max(all_assigned_distances):.4f} km")
    
    # Coverage analysis
    print(f"\n5. COVERAGE ANALYSIS:")
    print(f"   POIs within 0.5 km: {(np.array(all_assigned_distances) < 0.5).sum():,} ({100*(np.array(all_assigned_distances) < 0.5).sum()/I:.2f}%)")
    print(f"   POIs within 1.0 km: {(np.array(all_assigned_distances) < 1.0).sum():,} ({100*(np.array(all_assigned_distances) < 1.0).sum()/I:.2f}%)")
    print(f"   POIs within 2.0 km: {(np.array(all_assigned_distances) < 2.0).sum():,} ({100*(np.array(all_assigned_distances) < 2.0).sum()/I:.2f}%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 all_assigned_distances = [distance_matrix[i, assignments[i]] for i in range(I)]
#       3 print(f"\n4. DISTANCE STATISTICS:")
#       4 print(f"   Mean distance: {np.mean(all_assigned_distances):.4f} km")
#
# NameError: name 'assignments' is not defined
